# %%
import pandas as pd
import numpy as np

# %%
data_df=pd.read_csv("D:/study/Project/Custmore_churn_prediction/data/raw/TelcoCustomerChurn.csv")

# %%
data_df.shape
data_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CustomerID                     7043 non-null   str
#  1   Gender                         7043 non-null   str
#  2   Age                            7043 non-null   int64
#  3   Under30                        7043 non-null   str
#  4   SeniorCitizen                  7043 non-null   str
#  5   Married                        7043 non-null   str
#  6   Dependents                     7043 non-null   str
#  7   NumberofDependents             7043 non-null   int64
#  8   Country                        7043 non-null   str
#  9   State                          7043 non-null   str
#  10  City                           7043 non-null   str
#  11  ZipCode                        7043 non-null   int64
#  12  Latitude                       7043 non-null   float64
#  13  Longitude                      7043 non-null   float64
#  14  Population                     7043 non-null   int64
#  15  Quarter                        7043 non-null   str
#  16  ReferredaFriend                7043 non-null   str
#  17  Number_of_Referrals            7043 non-null   int64
#  18  TenureinMonths                 7043 non-null   int64
#  19  Offer                          3166 non-null   str
#  20  PhoneService                   7043 non-null   str
#  21  AvgMonthlyLongDistanceCharges  7043 non-null   float64
#  22  MultipleLines                  7043 non-null   str
#  23  InternetService                7043 non-null   str
#  24  InternetType                   5517 non-null   str
#  25  AvgMonthlyGBDownload           7043 non-null   int64
#  26  OnlineSecurity                 7043 non-null   str
#  27  OnlineBackup                   7043 non-null   str
#  28  DeviceProtectionPlan           7043 non-null   str
#  29  PremiumTechSupport             7043 non-null   str
#  30  StreamingTV                    7043 non-null   str
#  31  StreamingMovies                7043 non-null   str
#  32  StreamingMusic                 7043 non-null   str
#  33  UnlimitedData                  7043 non-null   str
#  34  Contract                       7043 non-null   str
#  35  PaperlessBilling               7043 non-null   str
#  36  PaymentMethod                  7043 non-null   str
#  37  MonthlyCharge                  7043 non-null   float64
#  38  TotalCharges                   7043 non-null   float64
#  39  TotalRefunds                   7043 non-null   float64
#  40  TotalExtraDataCharges          7043 non-null   int64
#  41  TotalLongDistanceCharges       7043 non-null   float64
#  42  TotalRevenue                   7043 non-null   float64
#  43  SatisfactionScore              7043 non-null   int64
#  44  CustomerStatus                 7043 non-null   str
#  45  ChurnLabel                     7043 non-null   str
#  46  ChurnScore                     7043 non-null   int64
#  47  CLTV                           7043 non-null   int64
#  48  ChurnCategory                  1869 non-null   str
#  49  ChurnReason                    1869 non-null   str
# dtypes: float64(8), int64(11), str(31)
# memory usage: 3.6 MB

# %%
drop_column=['ZipCode','City','Quarter','Country','CustomerID','ChurnScore','ChurnCategory','ChurnReason','CLTV','CustomerStatus','Dependents','ReferredaFriend','InternetService']
data_df=data_df.drop(columns=drop_column)
print(data_df.shape)
print(data_df.info())
# Out:
# (7043, 37)
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Gender                         7043 non-null   str
#  1   Age                            7043 non-null   int64
#  2   Under30                        7043 non-null   str
#  3   SeniorCitizen                  7043 non-null   str
#  4   Married                        7043 non-null   str
#  5   NumberofDependents             7043 non-null   int64
#  6   State                          7043 non-null   str
#  7   Latitude                       7043 non-null   float64
#  8   Longitude                      7043 non-null   float64
#  9   Population                     7043 non-null   int64
#  10  Number_of_Referrals            7043 non-null   int64
#  11  TenureinMonths                 7043 non-null   int64
#  12  Offer                          3166 non-null   str
#  13  PhoneService                   7043 non-null   str
#  14  AvgMonthlyLongDistanceCharges  7043 non-null   float64
#  15  MultipleLines                  7043 non-null   str
#  16  InternetType                   5517 non-null   str
#  17  AvgMonthlyGBDownload           7043 non-null   int64
#  18  OnlineSecurity                 7043 non-null   str
#  19  OnlineBackup                   7043 non-null   str
#  20  DeviceProtectionPlan           7043 non-null   str
#  21  PremiumTechSupport             7043 non-null   str
#  22  StreamingTV                    7043 non-null   str
#  23  StreamingMovies                7043 non-null   str
#  24  StreamingMusic                 7043 non-null   str
#  25  UnlimitedData                  7043 non-null   str
#  26  Contract                       7043 non-null   str
#  27  PaperlessBilling               7043 non-null   str
#  28  PaymentMethod                  7043 non-null   str
#  29  MonthlyCharge                  7043 non-null   float64
#  30  TotalCharges                   7043 non-null   float64
#  31  TotalRefunds                   7043 non-null   float64
#  32  TotalExtraDataCharges          7043 non-null   int64
#  33  TotalLongDistanceCharges       7043 non-null   float64
#  34  TotalRevenue                   7043 non-null   float64
#  35  SatisfactionScore              7043 non-null   int64
#  36  ChurnLabel                     7043 non-null   str
# dtypes: float64(8), int64(8), str(21)
# memory usage: 2.6 MB
# None

# %%
print(data_df.isnull().sum())
# Out:
# Gender                              0
# Age                                 0
# Under30                             0
# SeniorCitizen                       0
# Married                             0
# NumberofDependents                  0
# State                               0
# Latitude                            0
# Longitude                           0
# Population                          0
# Number_of_Referrals                 0
# TenureinMonths                      0
# Offer                            3877
# PhoneService                        0
# AvgMonthlyLongDistanceCharges       0
# MultipleLines                       0
# InternetType                     1526
# AvgMonthlyGBDownload                0
# OnlineSecurity                      0
# OnlineBackup                        0
# DeviceProtectionPlan                0
# PremiumTechSupport                  0
# StreamingTV                         0
# StreamingMovies                     0
# StreamingMusic                      0
# UnlimitedData                       0
# Contract                            0
# PaperlessBilling                    0
# PaymentMethod                       0
# MonthlyCharge                       0
# TotalCharges                        0
# TotalRefunds                        0
# TotalExtraDataCharges               0
# TotalLongDistanceCharges            0
# TotalRevenue                        0
# SatisfactionScore                   0
# ChurnLabel                          0
# dtype: int64

# %% [markdown]
# print(data_df.info())

# %%
cat_col=data_df.select_dtypes(include="object")
print(cat_col.columns)
# Out:
# Index(['Gender', 'Under30', 'SeniorCitizen', 'Married', 'State', 'Offer',
#        'PhoneService', 'MultipleLines', 'InternetType', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtectionPlan', 'PremiumTechSupport',
#        'StreamingTV', 'StreamingMovies', 'StreamingMusic', 'UnlimitedData',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'ChurnLabel'],
#       dtype='str')
# C:\Users\HP\AppData\Local\Temp\ipykernel_81288\3917066061.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_col=data_df.select_dtypes(include="object")

# %%
numeric_col=data_df.select_dtypes(include="number").columns
print(type(numeric_col))
# Out:
# <class 'pandas.Index'>

# %%
for col in cat_col:
    print(f"{col}:")
    print(cat_col[col].unique())
# Out:
# Gender:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# Under30:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# SeniorCitizen:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# Married:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# State:
# <ArrowStringArray>
# ['California']
# Length: 1, dtype: str
# Offer:
# <ArrowStringArray>
# [nan, 'Offer E', 'Offer D', 'Offer C', 'Offer B', 'Offer A']
# Length: 6, dtype: str
# PhoneService:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# MultipleLines:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# InternetType:
# <ArrowStringArray>
# ['DSL', 'Fiber Optic', 'Cable', nan]
# Length: 4, dtype: str
# OnlineSecurity:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# OnlineBackup:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# DeviceProtectionPlan:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# PremiumTechSupport:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# StreamingTV:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# StreamingMovies:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# StreamingMusic:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# UnlimitedData:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# Contract:
# <ArrowStringArray>
# ['Month-to-Month', 'One Year', 'Two Year']
# Length: 3, dtype: str
# PaperlessBilling:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# PaymentMethod:
# <ArrowStringArray>
# ['Bank Withdrawal', 'Credit Card', 'Mailed Check']
# Length: 3, dtype: str
# ChurnLabel:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
data_df["ChurnLabel"] = data_df["ChurnLabel"].map({
    'Yes':1,
    'No':0
})
print(data_df["ChurnLabel"].head())
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: ChurnLabel, dtype: int64

# %%
print(data_df.describe())
# Out:
#                Age  NumberofDependents     Latitude    Longitude  \
# count  7043.000000         7043.000000  7043.000000  7043.000000
# mean     46.509726            0.468692    36.197455  -119.756684
# std      16.750352            0.962802     2.468929     2.154425
# min      19.000000            0.000000    32.555828  -124.301372
# 25%      32.000000            0.000000    33.990646  -121.788090
# 50%      46.000000            0.000000    36.205465  -119.595293
# 75%      60.000000            0.000000    38.161321  -117.969795
# max      80.000000            9.000000    41.962127  -114.192901
#
#           Population  Number_of_Referrals  TenureinMonths  \
# count    7043.000000          7043.000000     7043.000000
# mean    22139.603294             1.951867       32.386767
# std     21152.392837             3.001199       24.542061
# min        11.000000             0.000000        1.000000
# 25%      2344.000000             0.000000        9.000000
# 50%     17554.000000             0.000000       29.000000
# 75%     36125.000000             3.000000       55.000000
# max    105285.000000            11.000000       72.000000
#
#        AvgMonthlyLongDistanceCharges  AvgMonthlyGBDownload  MonthlyCharge  \
# count                    7043.000000           7043.000000    7043.000000
# mean                       22.958954             20.515405      64.761692
# std                        15.448113             20.418940      30.090047
# min                         0.000000              0.000000      18.250000
# 25%                         9.210000              3.000000      35.500000
# 50%                        22.890000             17.000000      70.350000
# 75%                        36.395000             27.000000      89.850000
# max                        49.990000             85.000000     118.750000
#
#        TotalCharges  TotalRefunds  TotalExtraDataCharges  \
# count   7043.000000   7043.000000            7043.000000
# mean    2280.381264      1.962182               6.860713
# std     2266.220462      7.902614              25.104978
# min       18.800000      0.000000               0.000000
# 25%      400.150000      0.000000               0.000000
# 50%     1394.550000      0.000000               0.000000
# 75%     3786.600000      0.000000               0.000000
# max     8684.800000     49.790000             150.000000
#
#        TotalLongDistanceCharges  TotalRevenue  SatisfactionScore   ChurnLabel
# count               7043.000000   7043.000000        7043.000000  7043.000000
# mean                 749.099262   3034.379056           3.244924     0.265370
# std                  846.660055   2865.204542           1.201657     0.441561
# min                    0.000000     21.360000           1.000000     0.000000
# 25%                   70.545000    605.610000           3.000000     0.000000
# 50%                  401.440000   2108.640000           3.000000     0.000000
# 75%                 1191.100000   4801.145000           4.000000     1.000000
# max                 3564.720000  11979.340000           5.000000     1.000000
